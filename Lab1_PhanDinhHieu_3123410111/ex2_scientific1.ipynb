# %% [markdown]
# # ex2_scientific1
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$
# ## Bài làm
# ### Import thư viên

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

# %% [markdown]
# ### Sinh ngẫu nhiên hình tron

# %%
# Tạo ngẫu nhiên có tâm ( x,y) ( x : trục hoành , y : trục tung ) gồm màu, diện tích
N=50
x=np.random.rand(N)
y=np.random.rand(N)
colors=np.random.rand(N)
area=np.pi*(15*np.random.rand(N))**2 #15*np.random.rand(N)) tạo ngẫu nhiên bán kính với kích thước 0-15

# %% [markdown]
# #### Kiểm tra dữ liệu

# %%
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.01, 0.97]: 10 samples [[0.4159804  0.00983412 0.41418137 0.96696414 0.07874241 0.37667676
#  0.67929248 0.28794573 0.92433138 0.46313687]]
# + y: len=50, [0.02, 0.99]: 10 samples [[0.71792343 0.53769296 0.35652303 0.74122732 0.54907199 0.979819
#  0.59852788 0.48278528 0.98711866 0.94198522]]
# + colors: len=50, [0.02, 0.97]: 10 samples [[0.33959601 0.96878091 0.29533563 0.41678081 0.37919436 0.82179949
#  0.66534391 0.9486979  0.2933084  0.23953469]]
# + area: len=50, [0.27, 693.75]: 10 samples [[204.08221499   1.4627897  135.35003089  68.01659337 406.71554541
#  166.5197048  103.97207598 529.37995022 434.81003575 208.91843609]]

# %% [markdown]
# #### Hiển thị dữ liệu

# %%
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Kết thúc
